# %% [markdown]
# # Collection Manipulator

# %%
student = ["dev","bhargav", "manva","surendra"]
student.append("disha")
print(student)
# Out:
# ['dev', 'bhargav', 'manva', 'surendra', 'disha']

# %%
name = "Dev Thakkar"
age = 20

# Using f-string
print(f"My name is {name} and I am {age} years old.")

# Using format()
print("My name is {} and  I am {} years old.".format(name, age))
# Out:
# My name is Dev Thakkar and I am 20 years old.
# My name is Dev Thakkar and  I am 20 years old.

# %%
text = "hello world"

print(text.upper())   
print(text.lower())   
print(text.title())   
print(text.capitalize())
# Out:
# HELLO WORLD
# hello world
# Hello World
# Hello world

# %%
text = "Python"

reverse = text[::-1]
print("Reversed string:", reverse)
# Out:
# Reversed string: nohtyP

# %%
my_list = [1, 2, 3]
print("Before:", my_list)

my_list[0] = 10   # modifying element

print("After:", my_list)
# Out:
# Before: [1, 2, 3]
# After: [10, 2, 3]

# %%
student = ["dev","bhargav", "manva","surendra"]
student.append("disha")
print(student)
# Out:
# ['dev', 'bhargav', 'manva', 'surendra', 'disha']

# %%
student = {"name": "dev","age":20 }
print(student)
# Out:
# {'name': 'dev', 'age': 20}

# %%
pizza = ["cheese"]

print("Before:", pizza)

pizza.append("olives")
pizza.append("extra cheese")

print("After:", pizza)
# Out:
# Before: ['cheese']
# After: ['cheese', 'olives', 'extra cheese']

# %%
print("\n--- Display All Students ---")

for s in students:
    print(
        f"Student ID: {s['id']} | "
        f"Name: {s['name']} | "
        f"Age: {s['age']} | "
        f"Grade: {s['grade']} | "
        f"Subjects: {', '.join(s['subjects'])}"
    )
# Out:
# --- Display All Students ---
# Student ID: 120173 | Name: dev thakkar  | Age: 20 | Grade: b= | Subjects: maths english science

# %%
students = []

while True:
    print("\nWelcome to the Student Data Organizer!")
    print("\nSelect an option:")
    print("1. Add Student")
    print("2. Display All Students")
    print("3. Update Student Information")
    print("4. Delete Student")
    print("5. Display Subjects Offered")
    print("6. Exit")

    choice = input("\nEnter your choice: ")

    # Add Student
    if choice == "1":
        print("\nEnter student details:")

        student_id = input("Student ID: ")
        name = input("Name: ")
        age = int(input("Age: "))
        grade = input("Grade: ")
        dob = input("Date of Birth (YYYY-MM-DD): ")
        subjects = input("Subjects (comma-separated): ").split(",")

        student = {
            "id": student_id,
            "name": name,
            "age": age,
            "grade": grade,
            "dob": dob,
            "subjects": [s.strip() for s in subjects]
        }

        students.append(student)

        print("\nStudent added successfully!")

    # Display All Students
    elif choice == "2":
        print("\n--- Display All Students ---")

        if len(students) == 0:
            print("No students found.")
        else:
            for s in students:
                print(
                    f"Student ID: {s['id']} | "
                    f"Name: {s['name']} | "
                    f"Age: {s['age']} | "
                    f"Grade: {s['grade']} | "
                    f"Subjects: {', '.join(s['subjects'])}"
                )

    # Update Student
    elif choice == "3":
        sid = input("\nEnter Student ID to update: ")

        found = False

        for s in students:
            if s["id"] == sid:
                found = True

                s["name"] = input("Enter new name: ")
                s["age"] = int(input("Enter new age: "))
                s["grade"] = input("Enter new grade: ")

                print("Student information updated successfully!")

        if not found:
            print("Student not found.")

    # Delete Student
    elif choice == "4":
        sid = input("\nEnter Student ID to delete: ")

        found = False

        for s in students:
            if s["id"] == sid:
                students.remove(s)
                found = True
                print("Student deleted successfully!")
                break

        if not found:
            print("Student not found.")

    # Display Subjects
    elif choice == "5":
        print("\n--- Subjects Offered ---")

        all_subjects = []

        for s in students:
            all_subjects.extend(s["subjects"])

        unique_subjects = set(all_subjects)

        for subject in unique_subjects:
            print(subject)

    # Exit
    elif choice == "6":
        print("\nExiting program...")
        break

    else:
        print("\nInvalid choice. Please try again.")

print("\n--- Display All Students ---")

for s in students:
    print(
        f"Student ID: {s['id']} | "
        f"Name: {s['name']} | "
        f"Age: {s['age']} | "
        f"Grade: {s['grade']} | "
        f"Subjects: {', '.join(s['subjects'])}"
    )
# Out:
# Welcome to the Student Data Organizer!
#
# Select an option:
# 1. Add Student
# 2. Display All Students
# 3. Update Student Information
# 4. Delete Student
# 5. Display Subjects Offered
# 6. Exit
# Enter your choice:  1
# Enter student details:
# Student ID:  120173
# Name:  DEV
# Age:  20
# Grade:  B
# Date of Birth (YYYY-MM-DD):  2006-09-10
# Subjects (comma-separated):  ACCOUNT
# Student added successfully!
#
# Welcome to the Student Data Organizer!
#
# Select an option:
# 1. Add Student
# 2. Display All Students
# 3. Update Student Information
# 4. Delete Student
# 5. Display Subjects Offered
# 6. Exit
# Enter your choice:  1
# Enter student details:
# Student ID:  BHARGVA
# Name:  120174
# Age:  20
# Grade:  B
# Date of Birth (YYYY-MM-DD):  2006-10-10
# Subjects (comma-separated):  ACCOUNT
# Student added successfully!
#
# Welcome to the Student Data Organizer!
#
# Select an option:
# 1. Add Student
# 2. Display All Students
# 3. Update Student Information
# 4. Delete Student
# ...
